# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes

# Install Flash Attention 2 for softcapping support
import torch
if torch.cuda.get_device_capability()[0] >= 8:
    # !pip install --no-deps packaging ninja einops "flash-attn>=2.6.3"

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/gemma-2-2b",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.8: Fast Gemma2 patching. Transformers = 4.44.0.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.26.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth",
    random_state = 3407,
    use_rslora = False,
    loftq_config = None,
)
# Out:
# Unsloth 2024.8 patched 26 layers with 26 QKV layers, 26 O layers and 26 MLP layers.

# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset

df = pd.read_csv('synthetic_dataset.csv')
train_df, test_df = train_test_split(df, test_size=0.2, random_state=10)

train_dataset = Dataset.from_dict({
    'instruction': ['You are a great expert in the field of vegetarianism and recipes for vegans. You can see how recipes are built, which flavor combinations are the most popular.' for _ in range(len(train_df))],
    'input': train_df['question'].tolist(),
    'output': train_df['answer'].tolist()
})

test_dataset = Dataset.from_dict({
    'instruction': ['You are a great expert in the field of vegetarianism and recipes for vegans. You can see how recipes are built, which flavor combinations are the most popular.' for _ in range(len(test_df))],
    'input': test_df['question'].tolist(),
    'output': test_df['answer'].tolist()
})

# %%
alpaca_prompt = """Below is an instruction that describe  s your role, paired with an input that provides question you need to answer. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token

def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs = examples["input"]
    outputs = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN  # without this token generation goes on forever!
        texts.append(text)
    return {"text": texts}

train_dataset = train_dataset.map(formatting_prompts_func, batched=True)
test_dataset = test_dataset.map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/80 [00:00<?, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

training_args = TrainingArguments(
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    warmup_steps=5,
    num_train_epochs=3,
    learning_rate=2e-4,
    fp16=not torch.cuda.is_bf16_supported(),
    bf16=torch.cuda.is_bf16_supported(),
    logging_steps=1,
    optim="adamw_8bit",
    weight_decay=0.01,
    lr_scheduler_type="linear",
    seed=3407,
    output_dir="outputs",
)

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=train_dataset,
    dataset_text_field="text",
    max_seq_length=512,
    dataset_num_proc=2,
    packing=False,
    args=training_args,
)
# Out:
# Map (num_proc=2):   0%|          | 0/80 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 80 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 30
#  "-____-"     Number of trainable parameters = 20,766,720
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 01:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.913000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.119000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.833500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.550800</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.437100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.223100</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.946600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.832900</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.400100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.332200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.242300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.209900</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.951500</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.007200</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.938000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.974400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.115600</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.132500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.958200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.968900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.943500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.894200</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.942300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.860600</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.892700</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.791300</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.769800</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.850600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.850900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.768600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=30, training_loss=1.388383396466573, metrics={'train_runtime': 104.0159, 'train_samples_per_second': 2.307, 'train_steps_per_second': 0.288, 'total_flos': 763022048532480.0, 'train_loss': 1.388383396466573, 'epoch': 3.0})

# %%
responses = []
FastLanguageModel.for_inference(model)
for i in tqdm(test_dataset):
    inputs = tokenizer([alpaca_prompt.format(
        i['instruction'], # instruction
        i['input'], # input
        "") ], return_tensors = "pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens = 128, use_cache = True)
    response = tokenizer.batch_decode(outputs)
    answ = response[0][response[0].index('Response:')+len('Response:')+1:]
    if '<eos>' in answ:
        answ = answ[:answ.index('<eos>')]
    responses.append(answ)
# Out:
# 100%|██████████| 20/20 [02:03<00:00,  6.15s/it]

# %%
actual_answers = []
for i in test_dataset:
    actual_answers.append(i['output'])

# %%
# %pip install sentence_transformers
from sentence_transformers import SentenceTransformer, util
encoding = SentenceTransformer('all-MiniLM-L6-v2')

# %%
mean_score = []
for i in range(20):
    reference_embeddings = encoding.encode(actual_answers[i], convert_to_tensor=True)
    generated_embeddings = encoding.encode(responses[i], convert_to_tensor=True)
    cosine_scores = util.pytorch_cos_sim(generated_embeddings, reference_embeddings)
    mean_score.append(cosine_scores.diag().mean().item())

print('Mean score STS: ', np.array(mean_score).mean())
# Out:
# Mean score STS:  0.7510703101754188

# %%
for i,v in enumerate(responses):
  print(i)
  print(v)
  print('---------------------------------------------------')
# Out:
# 0
# The recipe suggests cooking the stuffed roast in the pressure cooker for 45 minutes, but it's important to note that this is an estimate based on the size of the roast and the desired doneness.  Actual cooking times may vary depending on these factors.
# ---------------------------------------------------
# 1
# There are various types of parasites, including bacteria, viruses, fungi, and protozoa. They can be transmitted through contaminated food, water, or direct contact with infected individuals.  These parasites can lead to various health issues, including digestive problems, weakened immune systems, and even more serious infections.
# ---------------------------------------------------
# 2
# To ensure your family enjoys healthy meals while reducing calories, focus on flavor combinations that are naturally low in calories.  Use herbs, spices, and fresh vegetables to enhance the taste without adding extra fat or sugar.  Experiment with different flavor profiles to keep things interesting.
# ---------------------------------------------------
# 3
# Here are some healthy side dishes and snacks that can be served with the fava bean dip:
#
# * **Fresh Fruit Platter:** A colorful assortment of sliced fruits like apples, pears, grapes, and berries.
# * **Roasted Vegetables:** A tray of roasted vegetables like carrots, broccoli, cauliflower, or sweet potatoes.
# * **Hummus Platter:** A platter of hummus with a variety of toppings like roasted chickpeas, olives, and veggies.
# * **Kale Chips:** Air-fried kale chips with a sprinkle of nutritional yeast for extra flavor.
# * **Zucchini Noodles:** A side of zucchini noodles with a sauce of
# ---------------------------------------------------
# 4
# To make kale a delicious part of your dinner meals, consider these tips:
#
# * **Flavor combinations:** Experiment with different flavor profiles like pesto, lemon, or garlic to enhance the taste of kale.
# * **Sauces and dressings:** Use flavorful sauces like pesto, chimichurri, or homemade dressings to add extra flavor and moisture to your kale dishes.
# * **Add protein:** Incorporate protein sources like grilled chicken, tofu, or beans to make the kale a satisfying main component of your meal.
# ---------------------------------------------------
# 5
# A hemoglobin A1c test provides valuable information about your blood sugar control over the past 2-3 months. It's a non-invasive way to assess your average blood sugar levels, which can help identify potential issues with diabetes management.
# ---------------------------------------------------
# 6
# The recommended cooking method for achieving the desired texture in the pears before stuffing is **steaming**. Steaming preserves the natural flavors and textures of the pears, making them perfect for stuffing.
# ---------------------------------------------------
# 7
# Common manmade chemicals that pose significant health risks include:
#
# * **Pesticides:** These are used in agriculture to control pests. They can be found in processed foods, especially fruits and vegetables.
# * **Plastics:** Many plastics contain harmful chemicals like phthalates, which can leach into food and water.
# * **Flame Retardants:** These are used in furniture, electronics, and textiles to prevent fires. They can be found in household products.
# * **Formaldehyde:** Used in building materials, it can be released into the air and ingested through dust.
# * **Bisphenol A (BPA):** Found in plastics,
# ---------------------------------------------------
# 8
# Flavored dairy products like yogurt are high in carbs and sugar, which are not allowed in a ketogenic diet.  To replace them, try using plain Greek yogurt or kefir, which are lower in carbs and can be flavored with fresh herbs or spices.
# ---------------------------------------------------
# 9
# The recipe provides the following nutritional breakdown:
#
# * **Protein:** 15 grams
# * **Fiber:** 10 grams
# * **Healthy Fats:** 10 grams
#
# This makes it a balanced meal with a good mix of protein, fiber, and healthy fats.
# ---------------------------------------------------
# 10
# Start small!  Even just 5 minutes of mindful breathing or stretching can make a big difference.  As you build your routine, you can add more time for meditation or yoga.  Remember, it's about finding what works for you!
# ---------------------------------------------------
# 11
# To strategically use rewards, focus on small, achievable goals that align with your long-term vision.  For example, you can reward yourself with a new recipe book or a trip to a local farmers' market for fresh produce after completing a specific task like cooking a healthy meal.  This approach helps you stay motivated while maintaining a balanced approach to rewards.
# ---------------------------------------------------
# 12
# Self-defeating behaviors are often rooted in negative self-talk and a lack of self-compassion.  Here's how you can address them:
#
# * **Recognize the Pattern:**  Identify the specific excuses or blame-shifting you use.  This helps you see the underlying pattern.
# * **Challenge the Thoughts:**  Question the validity of your excuses.  Are they really valid reasons for not making healthier choices?
# * **Focus on Progress:**  Instead of focusing on perfection, celebrate small steps towards healthier choices.  This shifts your mindset from failure to progress.
# * **Build Self-Compassion:**  Treat
# ---------------------------------------------------
# 13
# While family and friends are crucial, consider joining online communities, support groups, or even professional coaching for additional accountability and tailored advice.
# ---------------------------------------------------
# 14
# To minimize exposure to nitrogen dioxide, prioritize using public transportation or walking/biking near your home.  If you must drive, consider using hybrid or electric vehicles.  Also, consider using air purifiers with HEPA filters in your home.
# ---------------------------------------------------
# 15
# Shifting your mindset from frustration to positive action is crucial for breaking through weight plateaus.  Focus on progress, not perfection, and celebrate small victories along the way.  Remember that patience and consistency are key to long-term success.
# ---------------------------------------------------
# 16
# Here are some practical ways to increase your vitamin B3 intake:
#
# * **Focus on whole grains:**  Whole grains like brown rice, quinoa, and whole wheat pasta are excellent sources of vitamin B3.
# * **Choose fortified foods:**  Look for foods like cereals, breads, and breakfast bars that are fortified with vitamin B3.
# * **Include legumes:**  Legumes like lentils, chickpeas, and beans are great sources of vitamin B3.
# * **Consider supplements:**  If you're having trouble meeting your daily needs through diet alone, consider consulting with a healthcare professional about vitamin B3 supplements.
# ---------------------------------------------------
# 17
# The recipe suggests serving the "Vegan Chocolate Mousse" with a side of fresh fruit, such as berries or sliced bananas. This provides a balanced meal with both protein from the mousse and fiber from the fruit.
# ---------------------------------------------------
# 18
# To make a Greek-style salad even more flavorful, you can add:
#
# * **Fresh herbs:** Basil, oregano, thyme, mint, and dill are common additions to Greek salads.
# * **Olives:** Kalamata olives are a classic choice, but you can also experiment with other types like green or stuffed.
# * **Feta cheese:** A sprinkle of crumbled feta adds a salty, tangy note.
# * **Roasted red pepper relish:** A sweet and spicy addition for extra flavor.
# * **Lemon juice:** A squeeze of fresh lemon juice brightens up the salad.
#
# Remember to balance these additions with the
# ---------------------------------------------------
# 19
# Individuals can minimize exposure to pesticides by choosing organic produce whenever possible, supporting local farmers' markets, and advocating for stricter regulations on pesticide use.
# ---------------------------------------------------
